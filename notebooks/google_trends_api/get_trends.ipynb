# %% [markdown]
# ### Purpose
# This notebook serves to contact Pytrends API and retrieve relative popularities

# %%
import pandas as pd
from pytrends.request import TrendReq
import time
from time import sleep
from random import randint
import random
import calendar
import time

# %%
import random
import csv

pytrends = TrendReq(timeout=None, retries=10, backoff_factor=0.5)
batch_size = 4
predefined_element = "air travel"
unique_tags = []
i = -4 # Initial value is -4
## TODO Get your keywords from the csv files you have saved
#file_path = r"C:\School\Semester_1\Data_Wrangling\Data_in_the_wild_exam\data\intermediate\pytrends\auxiliary\2022\missing_pytrends_tags_2022.csv"
#df = pd.read_csv(file_path, sep=';')
#for ind in df.index:
#    unique_tags.append(df['tag'][ind])
unique_tags = ['horses', 'horse']
while i <= len(unique_tags) - 1:
    try:
        i += batch_size
        if i + batch_size > len(unique_tags) - 1:
             batch = unique_tags[i : len(unique_tags) - 1]
        else:
            batch = unique_tags[i : i + batch_size]
        # Add the pre-defined element
        batch.append(predefined_element)
        
        print(f'This is my batch {i} - {i+4}'.format(i=i))
        ## TODO Replace with your parameters
        pytrends.build_payload(batch, timeframe='2023-01-01 2023-01-31', geo='GB')
        response = pytrends.interest_over_time()

        current_GMT = time.gmtime()
        time_stamp = calendar.timegm(current_GMT)
        ## TODO replace with your path
        response.to_csv(f'C:\School\Semester_1\Data_Wrangling\Data_in_the_wild_exam\data\\raw\pytrends\\raw_results_2022\{time_stamp}_keywords.csv', sep=";")

        # Wait a little so I don't overwhelm the API with requests
        sleep(randint(5, 18))
        
        if i + batch_size > len(unique_tags) - 1:
            raise KeyError('done')
        
    except KeyError as error:
        print('Done! You can empty the leftover csv!')
        with open(r"C:\School\Semester_1\Data_Wrangling\Data_in_the_wild_exam\data\intermediate\pytrends\auxiliary\2022\leftover_tags.csv", "x", encoding='utf-8', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(['Empty! We are done!'])  # Write header

    ## It is common to get 429 exceptions from the API. In case we do get one,
    # we will interrupt the scraping for a while, saving our progress in a csv
    # After a while we shuffle the remaining tags to ensure that the request is random
    # This is done so that we don't repeat the same request, which is seemingly treated as suspicious by Google    
    except Exception as error:
            print(f'The request failed at batch {i} - {i+4}'.format(i=i))
            print('Noting the last index of the failed request')
            display(error)

            # Write the index to the file
            with open(r"C:\School\Semester_1\Data_Wrangling\Data_in_the_wild_exam\data\intermediate\pytrends\auxiliary\2022\failed_requests_index.txt", "x") as file:
                file.write(str(i))

            # Slice the unique_tags array based on the index
            unique_tags = unique_tags[i:]
            print(unique_tags)
            # TODO replace with your path
            with open(r"C:\School\Semester_1\Data_Wrangling\Data_in_the_wild_exam\data\intermediate\pytrends\auxiliary\2022\leftover_tags.csv", "w") as file:
                writer = csv.writer(file)
                writer.writerow(["tag"])  # Write header
                for tag in unique_tags:
                    writer.writerow([tag])

            #Reset i == -4.
            i = -4

            #Shuffle the array so we send random elements to confuse the API
            random.shuffle(unique_tags)
            sleep(randint(10, 15))

            continue
# Out:
# This is my batch 0 - 4
# Done! You can empty the leftover csv!
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 39
#      38     if i + batch_size > len(unique_tags) - 1:
# ---> 39         raise KeyError('done')
#      41 except KeyError as error:
#
# KeyError: 'done'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# Cell In[4], line 43
#      41 except KeyError as error:
#      42     print('Done! You can empty the leftover csv!')
# ---> 43     with open(r"C:\School\Semester_1\Data_Wrangling\Data_in_the_wild_exam\data\intermediate\pytrends\auxiliary\2022\leftover_tags.csv", "x", encoding='utf-8', newline='') as file:
#      44         writer = csv.writer(file)
#      45         writer.writerow(['Empty! We are done!'])  # Write header
#
# File ~\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'C:\\School\\Semester_1\\Data_Wrangling\\Data_in_the_wild_exam\\data\\intermediate\\pytrends\\auxiliary\\2022\\leftover_tags.csv'

# %% [markdown]
# ### For testing
# Some code with dummy arrays to simulate the requests

# %%
import random
import csv

checksum = 0
pytrends = TrendReq(timeout=None, retries=10, backoff_factor=0.5)
batch_size = 4
predefined_element = "air travel"
unique_tags = []
i = -4 # modify this value depending on progress
file_path = r"C:\School\Semester_1\Data_Wrangling\Data_in_the_wild_exam\data\intermediate\pytrends\auxiliary\2022\missing_pytrends_tags_2022.csv"
df = pd.read_csv(file_path, sep=';')
for ind in df.index:
    unique_tags.append(df['tag'][ind])
print(unique_tags)
while i <= len(unique_tags) - 1:
    try:
        i += batch_size
        checksum += 1
        print(i, len(unique_tags))
        if i + batch_size > len(unique_tags) - 1:
             batch = unique_tags[i : len(unique_tags) - 1]
        else:
            batch = unique_tags[i : i + batch_size]
        # Add the pre-defined element
        batch.append(predefined_element)
        
        print(f'This is my batch {i} - {i+4}'.format(i=i))
        print(batch)

        # Wait a little so I don't overwhelm the API with requests
        #make request
        #make the csv file with response
        #sleep(randint(5, 18))
        print('Sending request and simulating sleep!! ZZzzzzzZZZzzz')

        if i + batch_size > len(unique_tags) - 1:
            raise KeyError('done')

        if i > 10:
            raise Exception('Dummy exception at third req!!')
        
        
    except KeyError as error:
        print('Done! You can empty the leftover csv!')
        with open("leftover_tags.csv", "w", encoding='utf-8', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(['Empty! We are done!'])  # Write header
        
    except Exception as error:
            print(f'The request failed at batch {i} - {i+4}'.format(i=i))
            print('Noting the last index of the failed request')

            # Write the index to the file
            with open("failed_requests_index.txt", "w") as file:
                file.write(str(i))

            # Slice the unique_tags array based on the index
            unique_tags = unique_tags[i:]
            print(unique_tags)

            with open("leftover_tags.csv", "w", encoding='utf-8', newline='') as file:
                writer = csv.writer(file)
                writer.writerow(["tag"])  # Write header
                for tag in unique_tags:
                    writer.writerow([tag])

            #Reset i == -4.
            i = -4

            #Shuffle the array so we send random elements to confuse the API
            random.shuffle(unique_tags)

            continue
# Out:
# ['dave', 'surrey', 'houses of parliament', 'hiv', 'kardashians', 'us capitol riots', 'stowaways', 'sainsburys', 'covid pass', 'dave grohl', 'domestic abuse', 'puerto rico', 'malik faisal akram', 'reclaim these streets', 'disney', 'vienna', 'driverless cars', 'wiltshire', 'neighbours', 'dublin', 'dua lipa', 'portsmouth', 'tom watson', 'derbyshire', 'ashling murphy', 'paris agreement', 'jonas brothers', 'army', 'sage', 'defence', 'wolverhampton', 'trudy harrison', 'sussex', 'piers morgan', 'ocean rescue', 'sir lindsay hoyle', 'fire service', 'snp', 'anne sacoolas', 'cop27', 'el chapo', 'us election 2024', 'south yorkshire', '2022 world cup', 'manchester bombing', 'marijuana', 'priyanka chopra', 'al-shabaab', 'cardiff', 'tackling racism', 'child abuse inquiry', 'covid', 'west midlands', 'county durham', 'australian open, 2022', 'british airways', 'no more red - tackling knife crime', 'fukushima', 'gatwick', 'storm malik', 'meghan markle', 'washington', 'slovakia', 'article 16', 'nusrat ghani', 'celine dion', 'sean lock', 'the queens', 'terrorism', 'madeleine mccann', 'sir david amess', 'electric cars', 'murray v djokovic', 'measles', 'lockdown', 'larry king', 'pfizer-biontech vaccine', 'e-scooters', 'prince charles', 'samuel l jackson', 'utah', 'hugh jackman', 'covid-19', 'iain duncan smith', 'rome', 'tom moore', 'black lives matter', 'beijing winter olympics', 'olympics', 'mason greenwood', 'sue gray report', 'migrant crossings', 'tom tugendhat', 'ryan reynolds', 'covid 19', 'ariana debose', 'us capitol', 'sex attacks', 'downing street parties', 'australia bushfires', 'lashana lynch', 'west yorkshire', 'data and forensics', '12 days of christmas', 'wrexham fc', 'south dakota', 'brussels', 'harry dunn', 'kill the bill protests', 'gwyneth paltrow', 'arnold schwarzenegger', 'nobel prize', 'caroline flack', 'sag awards', 'neymar', 'energy crisis', "sport's coronavirus crisis", 'khloe kardashian', 'uk economy', 'west sussex', 'gcse', 'regina king', 'chernobyl', 'united kingdom', 'jason derulo', 'sir patrick vallance', 'leicestershire', 'net zero', 'jean-jacques savin', 'istanbul', 'gaming', 'asylum', 'hertfordshire', 'lionel messi', 'new mexico', 'bali', 'cruise ships', 'kyiv', 'volcano', 'croydon', 'racism in football', 'duchess of sussex', 'oldham', 'the ashes 2021/22', 'david carrick', 'the netherlands', 'west ham', 'hgv drivers', 'royal family', 'migrant crisis', 'pyongyang', 'liverpool terror attack', 'texas synagogue siege', 'bobbi-anne mcleod', 'global warming', 'prince george', 'jason sudeikis', 'royal dutch shell', 'nature crisis', 'marks and spencer', 'retail', 'alec baldwin', 'roads', 'daily climate show', 'arthur labinjo-hughes', 'cambo oil field', 'far-right', 'moderna vaccine', 'fgm', 'arlo parks', 'house of parliament', 'hillsborough', 'betty white', 'consumer', 'daily podcast', 'gabby petito', 'finance', 'duchess of cambridge', 'supply crisis', 'sir ed davey', 'halyna hutchins', 'sir keir starmer', 'highway code', 'tsunami', 'coral reef', 'grenfell tower', 'katie price', 'ian king business podcast', 'live', 'platinum jubilee', 'online safety bill', 'wyoming', 'storm corrie', 'rail', 'video games', 'weather', 'cctv', 'nikki grahame', 'essex lorry deaths', 'omicron', 'air', 'tokyo sevens 2013', 'tiger king', 'sarah harding', 'smart motorways', 'kim jong un', 'bafta', 'rugby', 'gamestop', 'middle east', 'cinema', 'berkshire', 'jerusalem', 'backstage podcast', 'star hobson', 'kurt cobain', 'georgia, us', 'tokyo 2020 olympics', 'islamic', 'dmx']
# 0 220
# This is my batch 0 - 4
# ['dave', 'surrey', 'houses of parliament', 'hiv', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 4 220
# This is my batch 4 - 8
# ['kardashians', 'us capitol riots', 'stowaways', 'sainsburys', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 8 220
# This is my batch 8 - 12
# ['covid pass', 'dave grohl', 'domestic abuse', 'puerto rico', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 12 220
# This is my batch 12 - 16
# ['malik faisal akram', 'reclaim these streets', 'disney', 'vienna', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# The request failed at batch 12 - 16
# Noting the last index of the failed request
# 
'smart motorways', 'sir david amess', 'sir lindsay hoyle', 'australian open, 2022', 'jonas brothers', 'air', 'south dakota', 'meghan markle', 'royal dutch shell', 'utah', 'wrexham fc', 'hugh jackman', 'kyiv', 'halyna hutchins', 'fukushima', 'lashana lynch', 'west midlands', 'dublin', 'priyanka chopra', 'betty white', 'tom moore', 'olympics', 'sag awards', 'manchester bombing', 'snp', 'west yorkshire', 'tom tugendhat', 'the netherlands', 'vienna', 'british airways', 'malik faisal akram', 'daily climate show', 'grenfell tower']
# 0 196
# This is my batch 0 - 4
# ['daily podcast', 'priyanka chopra', 'electric cars', 'terrorism', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 4 196
# This is my batch 4 - 8
# ["sport's coronavirus crisis", 'cambo oil field', 'manchester bombing', 'daily climate show', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 8 196
# This is my batch 8 - 12
# ['hertfordshire', 'arnold schwarzenegger', 'global warming', 'video games', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 12 196
# This is my batch 12 - 16
# ['sussex', 'sue gray report', 'tom tugendhat', 'duchess of cambridge', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# The request failed at batch 12 - 16
# Noting the last index of the failed request
# ['sussex', 'sue gray report', 'tom tugendhat', 'duchess of cambridge', 'wiltshire', 'snp', 'khloe kardashian', 'vienna', 'piers morgan', 'rome', 'smart motorways', 'sir david amess', 'ariana debose', 'pyongyang', 'backstage podcast', 'covid 19', 'chernobyl', 'united kingdom', 'gwyneth paltrow', 'neighbours', 'hillsborough', 'south yorkshire', 'retail', 'nature crisis', 'nikki grahame', 'kill the bill protests', 'west yorkshire', 'army', 'gamestop', 'driverless cars', 'e-scooters', 'nobel prize', 'australian open, 2022', 'celine dion', 'sir ed davey', 'utah', 'sir lindsay hoyle', 'net zero', 'fire service', 'dublin', 'lockdown', 'uk economy', 'istanbul', 'middle east', 'gabby petito', 'ocean rescue', 'sir patrick vallance', 'downing street parties', 'covid', 'british airways', 'article 16', 'beijing winter olympics', 'gatwick', 'slovakia', 'royal family', 'hugh jackman', 'tom moore', 'south dakota', 'bafta', 'storm malik', 'highway code', 'wrexham fc', 'cruise ships', 'supply crisis', 'gaming', 'no more red - tackling knife crime', 'portsmouth', 'kurt cobain', 'ashling murphy', 'reclaim these streets', 'washington', 'cardiff', 'prince george', 'mason greenwood', 'tokyo 2020 olympics', 'sage', 'new mexico', 'finance', 'air', 'dmx', 'gcse', 'kim jong un', 'black lives matter', 'star hobson', 'cop27', 'tackling racism', 'olympics', 'sex attacks', 'larry king', 'murray v djokovic', 'rugby', 'bobbi-anne mcleod', 'lashana lynch', 'ian king business podcast', 'jean-jacques savin', 'liverpool terror attack', 'caroline flack', 'sag awards', 'the netherlands', 'racism in football', 'defence', 'iain duncan smith', 'county durham', 'islamic', 'royal dutch shell', 'pfizer-biontech vaccine', 'wolverhampton', 'derbyshire', 'us capitol', 'samuel l jackson', 'croydon', 'far-right', 'tokyo sevens 2013', 'west midlands', 'jonas brothers', 'sir keir starmer', 'anne sacoolas', 'covid-19', 'asylum', 'us election 2024', 'migrant crisis', 'jason sudeikis', 'the queens', 'west sussex', 'moderna vaccine', 'ryan reynolds', 'essex lorry deaths', 'duchess of sussex', 'tsunami', '2022 world cup', 'west ham', 'marijuana', 'child abuse inquiry', 'nusrat ghani', 'regina king', 'katie price', 'hgv drivers', 'grenfell tower', 'trudy harrison', 'fgm', 'paris agreement', 'australia bushfires', 'volcano', 'leicestershire', 'georgia, us', 'meghan markle', 'rail', 'jason derulo', 'measles', 'data and forensics', 'arthur labinjo-hughes', '12 days of christmas', 'cinema', 'texas synagogue siege', 'migrant crossings', 'kyiv', 'oldham', 'prince charles', 'house of parliament', 'neymar', 'betty white', 'tiger king', 'coral reef', 'sean lock', 'consumer', 'jerusalem', 'live', 'alec baldwin', 'disney', 'al-shabaab', 'malik faisal akram', 'platinum jubilee', 'storm corrie', 'arlo parks', 'cctv', 'fukushima', 'brussels', 'madeleine mccann', 'harry dunn', 'omicron', 'halyna hutchins', 'bali', 'marks and spencer', 'weather']
# 0 184
# This is my batch 0 - 4
# ['bafta', 'supply crisis', 'wiltshire', 'sussex', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 4 184
# This is my batch 4 - 8
# ['iain duncan smith', 'khloe kardashian', 'grenfell tower', 'betty white', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 8 184
# This is my batch 8 - 12
# ['finance', 'leicestershire', 'sir keir starmer', 'prince charles', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 12 184
# This is my batch 12 - 16
# ['lockdown', 'gamestop', 'paris agreement', 'the queens', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# The request failed at batch 12 - 16
# Noting the last index of the failed request
# ['lockdown', 'gamestop', 'paris agreement', 'the queens', 'british airways', 'pfizer-biontech vaccine', 'katie price', 'storm corrie', 'oldham', 'covid', 'jerusalem', '2022 world cup', 'nature crisis', 'us election 2024', 'tom tugendhat', 'islamic', 'measles', 'omicron', 'utah', 'cardiff', 'istanbul', 'migrant crossings', 'brussels', 'sue gray report', 'county durham', 'rail', 'consumer', 'tsunami', 'tokyo sevens 2013', 'kim jong un', 'sex attacks', 'kyiv', 'kill the bill protests', 'sean lock', 'snp', 'celine dion', 'west midlands', 'disney', 'far-right', 'article 16', 'halyna hutchins', 'hgv drivers', 'murray v djokovic', 'new mexico', 'sir lindsay hoyle', 'hillsborough', 'portsmouth', 'ariana debose', 'racism in football', 'australian open, 2022', 'air', 'tiger king', 'cctv', 'data and forensics', 'arthur labinjo-hughes', 'royal family', 'derbyshire', 'volcano', 'moderna vaccine', 'lashana lynch', 'cruise ships', 'slovakia', 'downing street parties', 'us capitol', 'west ham', 'pyongyang', 'united kingdom', 'beijing winter olympics', 'gcse', 'croydon', 'smart motorways', 'regina king', 'cop27', 'house of parliament', 'texas synagogue siege', 'nobel prize', 'neighbours', 'gaming', 'anne sacoolas', 'south yorkshire', 'essex lorry deaths', 'jonas brothers', 'migrant crisis', 'georgia, us', 'liverpool terror attack', 'defence', 'nusrat ghani', 'royal dutch shell', 'jean-jacques savin', 'ryan reynolds', 'bobbi-anne mcleod', 'army', 'olympics', 'sage', 'gatwick', 'cinema', 'sir ed davey', 'al-shabaab', 'west sussex', 'piers morgan', 'rugby', 'child abuse inquiry', 'driverless cars', 'caroline flack', 'live', 'coral reef', 'platinum jubilee', 'neymar', 'washington', 'black lives matter', 'fukushima', 'tokyo 2020 olympics', 'gabby petito', 'highway code', 'covid 19', 'tom moore', 'australia bushfires', 'covid-19', 'gwyneth paltrow', 'fire service', 'star hobson', 'trudy harrison', 'samuel l jackson', 'meghan mark
royal family', 'storm corrie', 'beijing winter olympics', 'bobbi-anne mcleod', 'georgia, us', 'gamestop', 'rail', 'jonas brothers', 'madeleine mccann', 'reclaim these streets', 'jerusalem', 'nusrat ghani', 'istanbul', 'alec baldwin', 'vienna', 'marks and spencer', 'tsunami', 'snp', 'australian open, 2022', 'neighbours', 'tokyo sevens 2013', 'british airways', 'tom moore', 'the netherlands', 'arlo parks', 'nobel prize', 'consumer', 'racism in football', 'highway code', 'asylum', 'meghan markle', 'sage', 'al-shabaab', 'fire service', 'kill the bill protests', 'far-right', 'weather', 'celine dion', 'smart motorways', 'united kingdom']
# 0 160
# This is my batch 0 - 4
# ['croydon', 'british airways', 'beijing winter olympics', 'united kingdom', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 4 160
# This is my batch 4 - 8
# ['jason sudeikis', 'weather', 'royal family', 'tom moore', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 8 160
# This is my batch 8 - 12
# ['fukushima', 'cinema', 'regina king', 'driverless cars', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 12 160
# This is my batch 12 - 16
# ['lockdown', 'nobel prize', 'west yorkshire', 'gatwick', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# The request failed at batch 12 - 16
# Noting the last index of the failed request
# ['lockdown', 'nobel prize', 'west yorkshire', 'gatwick', 'house of parliament', 'us election 2024', 'arthur labinjo-hughes', 'west sussex', 'live', 'west ham', 'rugby', 'harry dunn', 'covid', 'tom tugendhat', 'pfizer-biontech vaccine', 'hillsborough', 'sue gray report', 'derbyshire', 'jason derulo', 'no more red - tackling knife crime', 'kyiv', 'samuel l jackson', 'australian open, 2022', 'west midlands', 'south yorkshire', 'defence', 'gabby petito', 'migrant crisis', 'highway code', 'omicron', 'nusrat ghani', 'alec baldwin', 'hgv drivers', 'gamestop', 'moderna vaccine', 'bobbi-anne mcleod', 'sage', 'net zero', 'rome', 'article 16', 'marks and spencer', 'kim jong un', 'essex lorry deaths', 'nikki grahame', 'asylum', 'ariana debose', 'consumer', 'migrant crossings', 'malik faisal akram', 'gaming', 'islamic', 'data and forensics', 'cruise ships', 'ryan reynolds', 'volcano', 'coral reef', 'jonas brothers', 'jerusalem', 'vienna', 'madeleine mccann', 'e-scooters', 'covid 19', 'tokyo sevens 2013', 'hugh jackman', 'sex attacks', 'downing street parties', 'halyna hutchins', 'istanbul', 'olympics', 'oldham', 'racism in football', 'fgm', 'tiger king', '2022 world cup', 'county durham', 'slovakia', 'the queens', 'sir patrick vallance', 'ian king business podcast', 'fire service', 'neymar', 'prince george', 'us capitol', 'marijuana', 'paris agreement', 'caroline flack', 'duchess of sussex', 'royal dutch shell', 'neighbours', 'sir lindsay hoyle', 'uk economy', 'sag awards', 'black lives matter', 'kill the bill protests', 'al-shabaab', 'wrexham fc', 'portsmouth', 'ashling murphy', 'lashana lynch', 'snp', 'storm malik', 'new mexico', 'dmx', 'washington', 'georgia, us', 'far-right', 'star hobson', 'tsunami', 'liverpool terror attack', 'child abuse inquiry', '12 days of christmas', 'disney', 'tackling racism', 'rail', 'larry king', 'storm corrie', 'bali', 'murray v djokovic', 'middle east', 'cop27', 'arlo parks', 'celine dion', 'air', 'trudy harrison', 'wolverhampton', 'covid-19', 'smart motorways', 'the netherlands', 'meghan markle', 'katie price', 'backstage podcast', 'retail', 'sir david amess', 'south dakota', 'chernobyl', 'sean lock', 'utah', 'reclaim these streets', 'anne sacoolas', 'mason greenwood', 'kurt cobain', 'pyongyang', 'platinum jubilee', 'army', 'piers morgan', 'dublin', 'cctv', 'ocean rescue']
# 0 148
# This is my batch 0 - 4
# ['sage', 'hgv drivers', 'bali', 'malik faisal akram', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 4 148
# This is my batch 4 - 8
# ['kim jong un', 'sag awards', 'consumer', 'volcano', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 8 148
# This is my batch 8 - 12
# ['house of parliament', 'covid-19', 'air', 'gamestop', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 12 148
# This is my batch 12 - 16
# ['racism in football', '12 days of christmas', 'sir david amess', 'essex lorry deaths', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# The request failed at batch 12 - 16
# Noting the last index of the failed request
# ['racism in football', '12 days of christmas', 'sir david amess', 'essex lorry deaths', 'washington', 'smart motorways', 'caroline flack', 'samuel l jackson', 'tom tugendhat', 'us election 2024', 'us capitol', 'disney', 'cctv', 'migrant crisis', 'ariana debose', '2022 world cup', 'covid 19', 'hillsborough', 'county durham', 'kill the bill protests', 'moderna vaccine', 'fgm', 'west ham', 'storm corrie', 'platinum jubilee', 'defence', 'asylum', 'slovakia', 'dublin', 'georgia, us', 'wrexham fc', 'oldham', 'retail', 'new mexico', 'utah', 'snp', 'royal dutch shell', 'cop27', 'gabby petito', 'prince george', 'article 16', 'migrant crossings', 'harry dunn', 'arlo parks', 'nikki grahame', 'lockdown', 'tackling racism', 'marijuana', 'sean lock', 'nobel prize', 'pfizer-biontech vaccine', 'live', 'anne sacoolas', 'al-shabaab', 'downing street parties', 'katie price', 'highway code', 'madeleine mccann', 'net zero', 'fire service', 'derbyshire', 'chernobyl', 'rugby', 'e-scooters', 'west sussex', 'liverpool terror attack', 'kyiv', 'hugh jackman', 'australian open, 2022', 'bobbi-anne mcleod', 'ashling murphy', 'jonas brothers', 'south dakota', 'wolverhampton', 'no more red - tackling knife crime', 'tiger king', 'neymar', 'backstage podcast', 'army', 'ryan reynolds', 'gatwick', 'sir patrick vallance', 'larry king', 'west yorkshire', 'halyna hutchins', 'tsunami', 'gaming', 'marks and spencer', 'kurt cobain', 'dmx', 'black lives matter', 'olympics', 'uk economy', 'storm malik', 'middle east', 'tokyo sevens 2013', 'sex attacks', 'rail', 'star hobson', 'omicron', 'west midlands', 'south yorkshire', 'duchess of sussex', 'neighbours', 'cruise ships', 'istanbul', 'sir lindsay hoyle', 'portsmouth', 'jerusalem', 'jason derulo', 'far-right', 'child abuse inquiry', 'ian king business podcast', 'meghan markle', 'vienna', 'the netherlands', 'celine dion', 'murray v djokovic', 'data and forensics', 'nusrat ghani', 'coral reef', 'piers morgan', 'mason greenwood', 'ocean rescue', 'the queens', 'alec baldwin', 'lashana lynch', 'reclaim these streets', 'arthur labinjo-hughes', 'pyongyang', 'rome', 'sue gray report', 'islamic', 'trudy harrison', 'covid', 'paris agreement']
# 0 136
# This is my batch 0 - 4
# ['black lives matter', 'murray v djokovic', 'army', 'arlo parks', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 4 136
# This is my batch 4 - 8
# ['mason greenwood', 'duchess of sussex', 'tsunami', 'al-shabaab', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 8 136
# This is my batch 8 - 12
# ['jonas brothers', 'meghan markle', 'olympics', 'marks and spencer', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 12 136
# This is my batch 12 - 16
# ['caroline flack', 'far-right', 'lockdown', 'west midlands', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# The request failed at batch 12 - 16
# Noting the last index of the failed request
# ['caroline flack', 'far-right', 'lockdown', 'west midlands', 'south dakota', 'fire service', 'kill the bill protests', 'neymar', 'migrant crossings', 'net zero', 'samuel l jackson', 'tokyo sevens 2013', 'live', 'us election 2024', 'bobbi-anne mcleod', 'utah', 'tackling racism', 'gatwick', 'omicron', 'tiger king', 'katie price', 'new mexico', 'coral reef', 'covid 19', 'fgm', 'jason derulo', 'australian open, 2022', 'jerusalem', 'sue gray report', 'slovakia', 'county durham', 'cruise ships', 'the netherlands', 'sir lindsay hoyle', 'hillsborough', 'us capitol', 'rail', 'ryan reynolds', 'snp', 'storm corrie', 'defence', 'west ham', 'georgia, us', 'racism in football', 'piers morgan', 'storm malik', 'smart motorways', 'star hobson', 'kyiv', 'alec baldwin', 'article 16', 'marijuana', 'ariana debose', 'anne sacoolas', 'south yorkshire', 'nusrat ghani', 'west sussex', 'asylum', 'nikki grahame', 'hugh jackman', 'cop27', 'wolverhampton', 'kurt cobain', 'downing street parties', '12 days of christmas', 'pfizer-biontech vaccine', 'ashling murphy', '2022 world cup', 'harry dunn', 'tom tugendhat', 'highway code', 'prince george', 'pyongyang', 'sean lock', 'arthur labinjo-hughes', 'no more red - tackling knife crime', 'gabby petito', 'moderna vaccine', 'dmx', 'celine dion', 'disney', 'oldham', 'cctv', 'portsmouth', 'essex lorry deaths', 'washington', 'uk economy', 'child abuse inquiry', 'sir david amess', 'platinum jubilee', 'halyna hutchins', 'covid', 'madeleine mccann', 'sir patrick vallance', 'chernobyl', 'dublin', 'west yorkshire', 'sex attacks', 'paris agreement', 'vienna', 'neighbours', 'migrant crisis', 'liverpool terror attack', 'ian king business podcast', 'larry king', 'the queens', 'royal dutch shell', 'trudy harrison', 'istanbul', 'wrexham fc', 'gaming', 'middle east', 'rugby', 'lashana lynch', 'derbyshire', 'rome', 'reclaim these streets', 'nobel prize', 'backstage podcast', 'e-scooters', 'retail', 'islamic', 'ocean rescue', 'data and forensics']
# 0 124
# This is my batch 0 - 4
# ['far-right', 'tiger king', 'pyongyang', 'celine dion', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 4 124
# This is my batch 4 - 8
# ['the queens', 'the netherlands', 'islamic', 'migrant crisis', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 8 124
# This is my batch 8 - 12
# ['slovakia', 'county durham', 'asylum', 'migrant crossings', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 12 124
# This is my batch 12 - 16
# ['rome', 'pfizer-biontech vaccine', 'sex attacks', 'katie price', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# The request failed at batch 12 - 16
# Noting the last index of the failed request
# ['rome', 'pfizer-biontech vaccine', 'sex attacks', 'katie price', 'nikki grahame', 'smart motorways', 'lashana lynch', 'oldham', 'sean lock', '12 days of christmas', 'fire service', 'ian king business podcast', 'sue gray report', 'net zero', 'storm malik', 'moderna vaccine', 'kill the bill protests', 'covid', 'dmx', 'halyna hutchins', 'tom tugendhat', 'cctv', 'defence', 'cruise ships', 'new mexico', 'jerusalem', 'disney', 'tokyo sevens 2013', 'child abuse inquiry', 'jason derulo', 'rail', 'essex lorry deaths', 'kyiv', 'ashling murphy', 'madeleine mccann', 'star hobson', 'australian open, 2022', 'south yorkshire', 'fgm', 'bobbi-anne mcleod', 'racism in football', 'piers morgan', 'trudy harrison', 'samuel l jackson', 'no more red - tackling knife crime', 'utah', 'live', 'sir patrick vallance', 'neighbours', 'reclaim these streets', 'larry king', 'west ham', 'chernobyl', 'lockdown', 'south dakota', 'sir lindsay hoyle', 'data and forensics', 'dublin', 'highway code', 'coral reef', 'west midlands', 'omicron', 'washington', 'alec baldwin', 'rugby', 'tackling racism', '2022 world cup', 'harry dunn', 'wolverhampton', 'hillsborough', 'west yorkshire', 'backstage podcast', 'hugh jackman', 'article 16', 'wrexham fc', 'downing street parties', 'kurt cobain', 'e-scooters', 'platinum jubilee', 'paris agreement', 'gaming', 'derbyshire', 'liverpool terror attack', 'marijuana', 'us election 2024', 'portsmouth', 'covid 19', 'caroline flack', 'sir david amess', 'prince george', 'retail', 'istanbul', 'royal dutch shell', 'uk economy', 'storm corrie', 'neymar', 'west sussex', 'us capitol', 'georgia, us', 'ariana debose', 'snp', 'gatwick', 'ryan reynolds', 'gabby petito', 'nobel prize', 'anne sacoolas', 'nusrat ghani', 'arthur labinjo-hughes', 'vienna', 'cop27', 'middle east', 'ocean rescue']
# 0 112
# This is my batch 0 - 4
# ['sir david amess', 'dmx', 'tom tugendhat', 'marijuana', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 4 112
# This is my batch 4 - 8
# ['west ham', 'nikki grahame', 'covid 19', 'smart motorways', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 8 112
# This is my batch 8 - 12
# ['fire service', 'istanbul', 'omicron', 'kyiv', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 12 112
# This is my batch 12 - 16
# ['gaming', 'uk economy', 'sean lock', 'sue gray report', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# The request failed at batch 12 - 16
# Noting the last index of the failed request
# ['gaming', 'uk economy', 'sean lock', 'sue gray report', 'net zero', 'tackling racism', 'paris agreement', 'neighbours', 'ryan reynolds', 'washington', 'retail', 'covid', 'alec baldwin', 'bobbi-anne mcleod', 'oldham', 'article 16', 'south yorkshire', 'west midlands', 'rail', 'portsmouth', 'star hobson', 'rome', 'royal dutch shell', 'gatwick', 'liverpool terror attack', 'cop27', 'west yorkshire', 'downing street parties', 'nusrat ghani', 'middle east', 'dublin', 'defence', 'south dakota', 'hillsborough', 'neymar', 'live', 'trudy harrison', 'ariana debose', 'kurt cobain', 'us election 2024', 'halyna hutchins', 'derbyshire', 'storm corrie', 'nobel prize', 'sex attacks', 'australian open, 2022', 'moderna vaccine', 'georgia, us', 'prince george', 'wrexham fc', 'coral reef', 'us capitol', 'fgm', 'racism in football', 'ocean rescue', 'tokyo sevens 2013', 'harry dunn', 'chernobyl', 'lashana lynch', 'storm malik', '2022 world cup', 'sir patrick vallance', 'lockdown', 'anne sacoolas', 'cruise ships', 'new mexico', 'cctv', 'pfizer-biontech vaccine', 'sir lindsay hoyle', 'data and forensics', 'madeleine mccann', 'larry king', 'hugh jackman', 'samuel l jackson', 'jason derulo', 'wolverhampton', 'e-scooters', 'platinum jubilee', 'caroline flack', 'piers morgan', 'ashling murphy', 'rugby', 'highway code', 'snp', 'arthur labinjo-hughes', 'backstage podcast', '12 days of christmas', 'jerusalem', 'ian king business podcast', 'west sussex', 'kill the bill protests', 'no more red - tackling knife crime', 'utah', 'gabby petito', 'child abuse inquiry', 'reclaim these streets', 'katie price', 'essex lorry deaths', 'disney', 'vienna']
# 0 100
# This is my batch 0 - 4
# ['royal dutch shell', 'lashana lynch', 'downing street parties', 'tokyo sevens 2013', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 4 100
# This is my batch 4 - 8
# ['trudy harrison', 'harry dunn', 'jerusalem', 'madeleine mccann', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 8 100
# This is my batch 8 - 12
# ['west midlands', 'hugh jackman', 'no more red - tackling knife crime', 'cctv', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 12 100
# This is my batch 12 - 16
# ['us capitol', 'anne sacoolas', 'nusrat ghani', 'us election 2024', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# The request failed at batch 12 - 16
# Noting the last index of the failed request
# ['us capitol', 'anne sacoolas', 'nusrat ghani', 'us election 2024', 'australian open, 2022', 'cruise ships', 'portsmouth', 'katie price', 'racism in football', 'rail', 'halyna hutchins', 'vienna', 'west sussex', 'sir patrick vallance', 'cop27', 'coral reef', 'oldham', 'new mexico', 'disney', 'ashling murphy', 'nobel prize', 'dublin', 'piers morgan', 'data and forensics', 'snp', 'wolverhampton', 'sir lindsay hoyle', 'moderna vaccine', 'paris agreement', 'chernobyl', 'essex lorry deaths', 'jason derulo', 'hillsborough', 'fgm', '2022 world cup', 'covid', 'sue gray report', 'sex attacks', 'utah', 'gaming', 'caroline flack', 'south dakota', 'platinum jubilee', 'e-scooters', 'ariana debose', 'alec baldwin', 'ryan reynolds', 'samuel l jackson', 'gatwick', 'live', 'georgia, us', 'retail', 'prince george', 'sean lock', 'kill the bill protests', 'article 16', 'tackling racism', 'neighbours', 'washington', 'bobbi-anne mcleod', 'larry king', 'rugby', 'reclaim these streets', 'ocean rescue', 'rome', 'uk economy', 'arthur labinjo-hughes', 'ian king business podcast', 'highway code', 'liverpool terror attack', 'kurt cobain', 'south yorkshire', 'storm corrie', 'lockdown', 'west yorkshire', 'middle east', 'backstage podcast', 'pfizer-biontech vaccine', 'gabby petito', 'storm malik', '12 days of christmas', 'derbyshire', 'wrexham fc', 'net zero', 'child abuse inquiry', 'neymar', 'star hobson', 'defence']
# 0 88
# This is my batch 0 - 4
# ['west sussex', 'fgm', 'data and forensics', 'neighbours', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 4 88
# This is my batch 4 - 8
# ['hillsborough', 'sir patrick vallance', 'south yorkshire', 'ariana debose', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 8 88
# This is my batch 8 - 12
# ['child abuse inquiry', 'neymar', 'retail', 'essex lorry deaths', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 12 88
# This is my batch 12 - 16
# ['new mexico', 'us capitol', 'washington', 'australian open, 2022', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# The request failed at batch 12 - 16
# Noting the last index of the failed request
# ['new mexico', 'us capitol', 'washington', 'australian open, 2022', 'prince george', 'moderna vaccine', 'ocean rescue', 'west yorkshire', 'disney', 'backstage podcast', 'us election 2024', 'snp', 'kill the bill protests', 'gaming', 'samuel l jackson', 'south dakota', 'wolverhampton', 'highway code', 'derbyshire', 'rail', 'reclaim these streets', 'kurt cobain', 'anne sacoolas', 'jason derulo', 'ashling murphy', 'dublin', 'sean lock', 'uk economy', 'bobbi-anne mcleod', 'sir lindsay hoyle', 'ian king business podcast', 'halyna hutchins', 'net zero', '12 days of christmas', 'tackling racism', 'cruise ships', 'pfizer-biontech vaccine', 'article 16', 'georgia, us', 'platinum jubilee', 'gabby petito', 'defence', 'wrexham fc', 'arthur labinjo-hughes', 'katie price', 'racism in football', 'star hobson', 'cop27', 'utah', 'alec baldwin', 'storm corrie', 'portsmouth', 'sex attacks', 'oldham', 'sue gray report', 'live', 'vienna', 'ryan reynolds', 'chernobyl', 'covid', 'coral reef', 'rugby', 'nobel prize', 'larry king', 'caroline flack', 'nusrat ghani', 'gatwick', 'storm malik', 'piers morgan', 'rome', 'paris agreement', '2022 world cup', 'lockdown', 'liverpool terror attack', 'middle east', 'e-scooters']
# 0 76
# This is my batch 0 - 4
# ['rome', 'australian open, 2022', 'coral reef', 'ian king business podcast', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 4 76
# This is my batch 4 - 8
# ['washington', 'dublin', 'west yorkshire', 'ryan reynolds', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 8 76
# This is my batch 8 - 12
# ['snp', 'utah', 'georgia, us', 'reclaim these streets', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 12 76
# This is my batch 12 - 16
# ['us capitol', 'net zero', 'cruise ships', 'disney', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# The request failed at batch 12 - 16
# Noting the last index of the failed request
# ['us capitol', 'net zero', 'cruise ships', 'disney', 'storm corrie', 'katie price', 'kill the bill protests', 'live', 'backstage podcast', 'ashling murphy', 'portsmouth', 'nusrat ghani', 'highway code', 'bobbi-anne mcleod', 'derbyshire', 'middle east', 'sean lock', 'ocean rescue', 'star hobson', 'uk economy', 'pfizer-biontech vaccine', 'us election 2024', 'arthur labinjo-hughes', 'tackling racism', 'rail', 'halyna hutchins', 'covid', 'nobel prize', 'paris agreement', 'e-scooters', 'platinum jubilee', '2022 world cup', 'kurt cobain', 'alec baldwin', 'larry king', 'sir lindsay hoyle', 'vienna', 'sue gray report', 'wrexham fc', 'chernobyl', 'rugby', 'samuel l jackson', 'jason derulo', '12 days of christmas', 'sex attacks', 'cop27', 'piers morgan', 'storm malik', 'gatwick', 'gabby petito', 'lockdown', 'defence', 'oldham', 'liverpool terror attack', 'racism in football', 'caroline flack', 'new mexico', 'wolverhampton', 'prince george', 'article 16', 'moderna vaccine', 'gaming', 'south dakota', 'anne sacoolas']
# 0 64
# This is my batch 0 - 4
# ['live', 'covid', 'anne sacoolas', 'wrexham fc', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 4 64
# This is my batch 4 - 8
# ['storm malik', 'paris agreement', 'sean lock', 'platinum jubilee', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 8 64
# This is my batch 8 - 12
# ['backstage podcast', 'new mexico', 'oldham', 'article 16', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 12 64
# This is my batch 12 - 16
# ['caroline flack', 'us capitol', 'cop27', 'gaming', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# The request failed at batch 12 - 16
# Noting the last index of the failed request
# ['caroline flack', 'us capitol', 'cop27', 'gaming', 'sex attacks', 'racism in football', 'portsmouth', 'arthur labinjo-hughes', 'moderna vaccine', 'sue gray report', 'star hobson', 'middle east', 'lockdown', 'gabby petito', 'south dakota', 'disney', 'pfizer-biontech vaccine', 'storm corrie', 'halyna hutchins', 'nobel prize', 'sir lindsay hoyle', 'chernobyl', 'samuel l jackson', 'us election 2024', 'kill the bill protests', 'uk economy', 'tackling racism', 'rail', 'defence', 'jason derulo', 'e-scooters', 'derbyshire', 'piers morgan', 'kurt cobain', 'gatwick', 'alec baldwin', 'cruise ships', 'ocean rescue', '2022 world cup', 'bobbi-anne mcleod', 'wolverhampton', 'ashling murphy', 'prince george', 'nusrat ghani', 'vienna', 'highway code', 'rugby', 'net zero', 'larry king', 'katie price', '12 days of christmas', 'liverpool terror attack']
# 0 52
# This is my batch 0 - 4
# ['sex attacks', 'storm corrie', 'liverpool terror attack', 'racism in football', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 4 52
# This is my batch 4 - 8
# ['sue gray report', 'gabby petito', 'cruise ships', 'arthur labinjo-hughes', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 8 52
# This is my batch 8 - 12
# ['vienna', 'sir lindsay hoyle', 'halyna hutchins', 'derbyshire', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 12 52
# This is my batch 12 - 16
# ['cop27', 'middle east', 'rugby', 'portsmouth', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# The request failed at batch 12 - 16
# Noting the last index of the failed request
# ['cop27', 'middle east', 'rugby', 'portsmouth', 'south dakota', 'ocean rescue', 'disney', 'ashling murphy', 'us election 2024', 'kurt cobain', '12 days of christmas', 'piers morgan', '2022 world cup', 'bobbi-anne mcleod', 'star hobson', 'gatwick', 'katie price', 'jason derulo', 'larry king', 'chernobyl', 'rail', 'alec baldwin', 'uk economy', 'moderna vaccine', 'nobel prize', 'samuel l jackson', 'wolverhampton', 'caroline flack', 'gaming', 'lockdown', 'prince george', 'defence', 'nusrat ghani', 'us capitol', 'kill the bill protests', 'e-scooters', 'highway code', 'net zero', 'pfizer-biontech vaccine', 'tackling racism']
# 0 40
# This is my batch 0 - 4
# ['ashling murphy', 'tackling racism', 'nusrat ghani', 'uk economy', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 4 40
# This is my batch 4 - 8
# ['rugby', 'bobbi-anne mcleod', 'kurt cobain', 'prince george', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 8 40
# This is my batch 8 - 12
# ['defence', 'pfizer-biontech vaccine', 'kill the bill protests', 'middle east', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 12 40
# This is my batch 12 - 16
# ['highway code', 'wolverhampton', 'katie price', '12 days of christmas', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# The request failed at batch 12 - 16
# Noting the last index of the failed request
# ['highway code', 'wolverhampton', 'katie price', '12 days of christmas', 'star hobson', 'chernobyl', 'jason derulo', 'net zero', 'disney', 'lockdown', 'gaming', 'caroline flack', 'portsmouth', 'us capitol', 'e-scooters', 'nobel prize', 'ocean rescue', 'moderna vaccine', '2022 world cup', 'gatwick', 'south dakota', 'larry king', 'cop27', 'us election 2024', 'piers morgan', 'alec baldwin', 'samuel l jackson', 'rail']
# 0 28
# This is my batch 0 - 4
# ['piers morgan', 'samuel l jackson', 'alec baldwin', '2022 world cup', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 4 28
# This is my batch 4 - 8
# ['wolverhampton', 'gaming', 'ocean rescue', 'moderna vaccine', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 8 28
# This is my batch 8 - 12
# ['larry king', '12 days of christmas', 'cop27', 'us capitol', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 12 28
# This is my batch 12 - 16
# ['us election 2024', 'gatwick', 'chernobyl', 'jason derulo', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# The request failed at batch 12 - 16
# Noting the last index of the failed request
# ['us election 2024', 'gatwick', 'chernobyl', 'jason derulo', 'e-scooters', 'disney', 'star hobson', 'south dakota', 'caroline flack', 'lockdown', 'katie price', 'portsmouth', 'net zero', 'rail', 'nobel prize', 'highway code']
# 0 16
# This is my batch 0 - 4
# ['portsmouth', 'us election 2024', 'jason derulo', 'chernobyl', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 4 16
# This is my batch 4 - 8
# ['disney', 'nobel prize', 'gatwick', 'highway code', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 8 16
# This is my batch 8 - 12
# ['rail', 'star hobson', 'south dakota', 'lockdown', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# 12 16
# This is my batch 12 - 16
# ['katie price', 'net zero', 'caroline flack', 'air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# Done! You can empty the leftover csv!
# 16 16
# This is my batch 16 - 20
# ['air travel']
# Sending request and simulating sleep!! ZZzzzzzZZZzzz
# Done! You can empty the leftover csv!
