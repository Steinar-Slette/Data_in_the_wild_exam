# %%
import pandas as pd
from pytrends.request import TrendReq
import time
from time import sleep
from random import randint
import random
import calendar
import time

# %%
# opening the file in read mode 
my_file = open("unique_tags_save.txt", "r", encoding="utf-8") 
  
# reading the file 
data = my_file.read() 
  
# replacing end of line('/n') with ' ' and 
# splitting the text it further when '.' is seen. 
unique_tags = data.split("\n") 

# printing the data 
print(unique_tags)
# Out:
# ['world health organization (who)', 'coronavirus vaccines', 'coronavirus pandemic', 'skip to content', 'accessibility help', 'prince andrew, duke of york', 'ghislaine maxwell', 'jeffrey epstein', 'global supply chain management', 'hong kong', 'cathay pacific', 'tesla', 'electric cars', 'united states', 'uk banking', 'santander group', 'banking', 'communications satellites', 'elon musk', 'spacex', 'china', 'space', 'stock markets', 'theatre', 'joanna lumley', 'film', 'new year honours', 'daniel craig', 'james bond', 'music', 'hydrogen vehicles', 'business in africa', 'climate change', 'africa economy', 'south africa', 'photography', 'france', 'documentary photography', 'christmas', 'germany', 'zoos and zoology', 'christmas trees', 'animals', 'berlin', 'colorado', 'wildfires', 'kim kardashian', 'television', 'meta', 'nfts', 'semiconductors', 'astronomy', 'nasa', 'european space agency', 'the universe', 'james webb space telescope', 'hubble telescope', 'space exploration', 'india', 'app
# ...

# %%
pytrends = TrendReq(timeout=None, retries=10, backoff_factor=0.5)
batch_size = 4
predefined_element = "air travel"
i = 1633 # modify this value depending on progress
while i <= len(unique_tags) - 1:
    try:
        i += batch_size
        print(i, len(unique_tags))
        # Extract the batch of 4 elements
        if i + batch_size > len(unique_tags) - 1:
             batch = unique_tags[i : len(unique_tags) - 1] 
        else:
            batch = unique_tags[i : i + batch_size]
        # Add the pre-defined element
        batch.append(predefined_element)
        
        print(batch)
        pytrends.build_payload(batch, timeframe='2022-01-01 2022-01-31', geo='GB')
        
        ##Drop last column from the response
        # Last column is an unnecessary boolean
        response = pytrends.interest_over_time()

        current_GMT = time.gmtime()
        time_stamp = calendar.timegm(current_GMT)
        response.to_csv(f"{time_stamp}_keywords.csv", sep=";")

        # Wait a little so I don't overwhelm the API with requests
        sleep(randint(5, 18))
    except Exception as error:
            for t in batch[:-1]:
                unique_tags.append(t)
            sleep(random.uniform(34.1,62.7))
            continue
# Out:
# 1637 5345
# ['Uganda', 'Anglia Ruskin University', 'National parks', 'US immigration', 'air travel']
# 1641 5345
# ['Cuba', 'Haiti', 'Arsenal Women', 'Manchester City Women', 'air travel']
# 1645 5345
# ['Wisconsin', 'Southampton', 'Alexei Navalny', 'New England Revolution', 'air travel']
# 1649 5345
# ['Deafness and hearing loss', 'Rose Ayling-Ellis', 'Ben Wallace', 'Zac Goldsmith', 'air travel']
# 1653 5345
# ['Competition and Markets Authority', 'Instagram', 'Alexa Chung', 'Ellie Goulding', 'air travel']
# 1657 5345
# ['Guy Hands', 'Military', 'Ministry of Defence', 'easyJet', 'air travel']
# 1661 5345
# ['House prices', 'Rangers', 'Nottingham Forest', 'Chelsea', 'air travel']
# 1665 5345
# ['Executive pay and bonuses', 'Corporate governance', 'Priti Patel', 'Tobacco industry', 'air travel']
# 1669 5345
# ['BHP', 'Leo Tolstoy', 'Paula Rego', 'Neuroscience', 'air travel']
# 1673 5345
# ['Islamophobia', 'Sayeeda Warsi', 'Asteroids', "Don't Look Up", 'air travel']
# 1677 5345
# ...

# %% [markdown]
# ### Get SkyNews tags

# %%
import pandas as pd
import ast

skynews_2022_all_tags = []
skynews_2022_unique_tags = []
# Specify the path to your CSV file
csv_file_path = r"C:\School\Semester_1\Data_Wrangling\Data_in_the_wild_exam\data\raw\skynews\articles\2022-01_skynews_articles.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path, sep=';')

# Choose the column you're interested in (replace 'Tags' with your actual column name)
selected_column = 'Tags'

# Filter non-empty and unique rows from the selected column
skynews_2022_all_tags = df[selected_column].apply(ast.literal_eval)

# Print the non-empty, unique rows
for arr in skynews_2022_all_tags:
    for tag in arr:
        if tag not in skynews_2022_unique_tags:
            skynews_2022_unique_tags.append(tag)

print('These are the unique SkyNews tags for 2022:\n', skynews_2022_unique_tags)
print('There are ', len(skynews_2022_unique_tags), 'unique tags in total')
# Out:
# These are the unique SkyNews tags for 2022:
# ...

# %% [markdown]
# ### Get Guardian Tags

# %%
import pandas as pd
import ast

guardian_2022_all_tags = []
guardian_2022_unique_tags = []
# Specify the path to your CSV file
csv_file_path = r"C:\School\Semester_1\Data_Wrangling\Data_in_the_wild_exam\data\raw\guardian\2022-01-31_guardian.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path, sep=';')

# Choose the column you're interested in (replace 'Tags' with your actual column name)
selected_column = 'Tags'

# Filter non-empty and unique rows from the selected column
guardian_2022_all_tags = df[selected_column].apply(ast.literal_eval)

# Print the non-empty, unique rows
for arr in guardian_2022_all_tags:
    for tag in arr:
        if tag not in guardian_2022_unique_tags:
            guardian_2022_unique_tags.append(tag)

print('These are the unique Guardian tags for 2022:\n', guardian_2022_unique_tags)
print('There are ', len(guardian_2022_unique_tags), 'unique tags in total')
# Out:
# These are the unique Guardian tags for 2022:
# ...

# %% [markdown]
# ### Get BBC Tags

# %%
import pandas as pd
import ast

bbc_2022_all_tags = []
bbc_2022_unique_tags = []
# Specify the path to your CSV file
csv_file_path = r"C:\School\Semester_1\Data_Wrangling\Data_in_the_wild_exam\data\raw\bbc\articles\BBC_2022.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path, sep=';')

# Choose the column you're interested in (replace 'Tags' with your actual column name)
selected_column = 'Tags'

# Filter non-empty and unique rows from the selected column
bbc_2022_all_tags = df[selected_column].apply(ast.literal_eval)

# Print the non-empty, unique rows
for arr in bbc_2022_all_tags:
    for tag in arr:
        if tag not in bbc_2022_unique_tags:
            bbc_2022_unique_tags.append(tag)

print('These are the unique BBC tags for 2022:\n', bbc_2022_unique_tags)
print('There are ', len(bbc_2022_unique_tags), 'unique tags in total')
# Out:
# These are the unique BBC tags for 2022:
# ...

# %% [markdown]
# ### Get all the unique tags across ALL news sources

# %%
skynews_2022_unique_tags_set = set(skynews_2022_unique_tags)
guardian_2022_unique_tags_set = set(guardian_2022_unique_tags)
bbc_2022_unique_tags_set = set(bbc_2022_unique_tags)

required_2022_tags = skynews_2022_unique_tags_set.union(guardian_2022_unique_tags_set, bbc_2022_unique_tags_set)

print(list(required_2022_tags))
# Out:
# ['sussex', 'Port Vale', 'Southwark Playhouse', 'Sex and the City 2', 'Bob Dylan', 'Tonga volcano', 'Opera North', 'covid pass', 'Alan Sugar', 'Smoking', 'Chess', 'Rihanna', 'liverpool terror attack', 'Australian foreign policy', 'Vancouver Canucks', 'Blue Origin', 'scotland', 'Education', 'schools', 'And Just Like That', 'Extreme weather', 'Empoli', "Iran's nuclear programme", 'Diane Morgan', 'Social mobility', 'Australian music', 'derbyshire', 'Cricket Australia', 'scarlett johansson', 'Ghislaine Maxwell', 'WhatsApp', 'mauritius', 'Substack', 'bolivia', 'michael b jordan', 'Andrew Mitchell', 'tsunami', 'Headphones', 'Cottages', 'islamic', 'IVF', 'Jeremy Hunt', 'WNBA', 'Neil Young', 'Australian universities', 'Rafael Nadal', 'electric cars', 'Don Warrington', 'downing street parties', 'Alvin Ailey', 'Games', 'Biodiversity', 'Hunter Valley', 'Sport politics', 'Dolphins', 'oceans', 'Luxury travel', 'Michael Flynn', 'coronavirus', 'Jo Cox', 'Sons of Kemet', 'Royal Navy', 'Broadway', 'Be
# ...

# %% [markdown]
# ### Get all the tags for which we have pytrends data, along with time series relative popularity. This is to preserve the truly raw data before normalization

# %%
import os
import pandas as pd

# Specify the directory where your CSV files are located
directory = r"C:\School\Semester_1\Data_Wrangling\Data_in_the_wild_exam\google_trends_api\raw_results_2022"

# List all CSV files in the directory
csv_files = [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.csv')]

# Initialize an empty DataFrame
request_tags = pd.DataFrame()

# Concatenate all CSV files along the column axis
for file in csv_files:
    df = pd.read_csv(file, sep=';')
    request_tags = pd.concat([request_tags, df], axis=1)

# Specify the output CSV file path
output_csv_path = r"C:\School\Semester_1\Data_Wrangling\Data_in_the_wild_exam\data\intermediate\concated_results_2022\all_tags_2022.csv"

# Write the merged DataFrame to a CSV file with semicolon (;) as the delimiter
request_tags.to_csv(output_csv_path, sep=';', index=False)

# Display a message indicating successful writing
print(f'Merged data has been written to {output_csv_path}')
# Out:
# Merged data has been written to C:\School\Semester_1\Data_Wrangling\Data_in_the_wild_exam\data\intermediate\concated_results_2022\all_tags_2022.csv

# %% [markdown]
# ### Get all the UNIQUE tags from the pytrends data, so that we can check that we didn't miss any
#
# We must create a different version of the all_tags_2022.csv file, in which we don't have the duplicates.

# %%
import os
import pandas as pd

pytrends_unique_tags = []
# Specify the directory where your CSV files are located
directory = r"C:\School\Semester_1\Data_Wrangling\Data_in_the_wild_exam\google_trends_api\raw_results_2022"

# List all CSV files in the directory
csv_files = [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.csv')]

# Initialize an empty DataFrame
request_tags = pd.DataFrame()

# Concatenate all CSV files along the column axis
for file in csv_files:
    df = pd.read_csv(file, sep=';')
    request_tags = pd.concat([request_tags, df], axis=1)

request_tags = request_tags.loc[:,~request_tags.columns.duplicated()]
# Specify the path to your CSV file
output_csv_path =  r"C:\School\Semester_1\Data_Wrangling\Data_in_the_wild_exam\data\intermediate\concated_results_2022\all_unique_tags_2022.csv"

# Write the merged DataFrame to a CSV file with semicolon (;) as the delimiter
request_tags.to_csv(output_csv_path, sep=';', index=False)

# Read the CSV file into a DataFrame
df = pd.read_csv(output_csv_path, sep=';')

for column in df.columns:
    # Check if the column is not already in the array
    if column not in pytrends_unique_tags:
        # Add the column to the array
        pytrends_unique_tags.append(column)

# Print the unique columns
print(pytrends_unique_tags)
print(len(pytrends_unique_tags))
# Out:
# ['date', 'accessibility help', 'prince andrew, duke of york', 'ghislaine maxwell', 'jeffrey epstein', 'air travel', 'isPartial', 'electric cars', 'united states', 'uk banking', 'santander group', 'joanna lumley', 'film', 'new year honours', 'daniel craig', 'james bond', 'music', 'hydrogen vehicles', 'business in africa', 'climate change', 'africa economy', 'south africa', 'photography', 'meta', 'nfts', 'semiconductors', 'astronomy', 'nasa', 'european space agency', 'the universe', 'james webb space telescope', 'hubble telescope', 'space exploration', 'india', 'apple', 'iphones', 'omicron variant', 'joe biden', 'uk royal family', 'fireworks', 'netherlands', 'antarctic', 'severe weather', 'republican party', 'twitter', 'us politics', 'netflix', 'aviation safety', 'telecommunication', '5g', 'asia', 'uighurs', 'companies', 'silicon valley', 'fraud', 'rail travel', 'reality check', 'beer', 'philadelphia', 'pennsylvania', 'angela rayner', "prime minister's questions", 'oil & gas industry',
# ...

# %% [markdown]
# ### Now we may check whether we have collected data for all the required tags

# %%
# Print elements in array A but not in array B
missing_tags = [element for element in required_2022_tags if element not in pytrends_unique_tags]

print(missing_tags)
# Out:
# ['mauritius', 'paisley', 'foster care', 'aberystwyth university', 'rupert murdoch', 'impact of the covid-19 pandemic on children', 'murder of bibaa henry and nicole smallman', "burkina faso coup d'état 2022", 'transplants', 'exploration of the moon', 'éric zemmour', 'deafness and hearing-impairment', 'the royal family and the media', 'shielding', 'genetic engineering', 'christianity', 'tourism', 'narborough', 'policing', 'hm courts service', 'theresa may', 'engineering', 'jeffrey epstein death', 'soviet union', 'coal mining', 'uk government', 'the church of england', 'N/A', 'coronavirus testing', 'nigeria', 'moderna', 'public health', 'plastic', 'stars', 'disability', 'sudan crisis', 'falklands war', 'sarah everard murder', 'lgbt', 'eating disorders', 'care homes', 'pregnancy', 'burnley', 'dating apps', 'sign language', 'space launch system (sls)', 'psychology', 'british armed forces', 'contact tracing', "tigray people's liberation front", 'valérie pécresse', 'women’s rights in afric
# ...

# %%
## Get missing 2022 trends
import random
import csv

pytrends = TrendReq(timeout=None, retries=10, backoff_factor=0.5)
batch_size = 4
predefined_element = "air travel"
i = -4 # Initial value is -4
unique_tags = missing_tags
while i <= len(unique_tags) - 1:
    try:
        i += batch_size
        if i + batch_size > len(unique_tags) - 1:
             batch = unique_tags[i : len(unique_tags) - 1]
        else:
            batch = unique_tags[i : i + batch_size]
        # Add the pre-defined element
        batch.append(predefined_element)
        
        print(f'This is my batch {i} - {i+4}'.format(i=i))

        pytrends.build_payload(batch, timeframe='2022-01-01 2022-01-31', geo='GB')
        response = pytrends.interest_over_time()

        current_GMT = time.gmtime()
        time_stamp = calendar.timegm(current_GMT)
        response.to_csv(f"{time_stamp}_keywords.csv", sep=";")

        # Wait a little so I don't overwhelm the API with requests
        sleep(randint(5, 18))
        
        if i + batch_size > len(unique_tags) - 1:
            raise KeyError('done')
        
    except KeyError as error:
        print('Done! You can empty the leftover csv!')
        with open("leftover_tags.csv", "w", encoding='utf-8', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(['Empty! We are done!'])  # Write header
        
    except Exception as error:
            print(f'The request failed at batch {i} - {i+4}'.format(i=i))
            print('Noting the last index of the failed request')

            # Write the index to the file
            with open("failed_requests_index.txt", "w") as file:
                file.write(str(i))

            # Slice the unique_tags array based on the index
            unique_tags = unique_tags[i:]
            print(unique_tags)

            with open("leftover_tags.csv", "w", encoding='utf-8', newline='') as file:
                writer = csv.writer(file)
                writer.writerow(["tag"])  # Write header
                for tag in unique_tags:
                    writer.writerow([tag])

            #Reset i == -4.
            i = -4

            #Shuffle the array so we send random elements to confuse the API
            random.shuffle(unique_tags)

            continue
# Out:
# This is my batch 0 - 4
# This is my batch 4 - 8
# This is my batch 8 - 12
# This is my batch 12 - 16
# This is my batch 16 - 20
# This is my batch 20 - 24
# This is my batch 24 - 28
# This is my batch 28 - 32
# This is my batch 32 - 36
# This is my batch 36 - 40
# This is my batch 40 - 44
# This is my batch 44 - 48
# The request failed at batch 44 - 48
# Noting the last index of the failed request
# ...

# %%
## Get missing tags

pytrends = TrendReq(timeout=None, retries=10, backoff_factor=0.5)

batch = ['uk government', 'the vegan society -', 'air travel']

pytrends.build_payload(batch, timeframe='2022-01-01 2022-01-31', geo='GB')

##Drop last column from the response
# Last column is an unnecessary boolean
response = pytrends.interest_over_time()

current_GMT = time.gmtime()
time_stamp = calendar.timegm(current_GMT)
response.to_csv(f"{time_stamp}_keywords.csv", sep=";")
